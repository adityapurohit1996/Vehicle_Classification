# %% [markdown]
# # Task 0: Warm Up

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Unzip from Google Drive (OPTIONAL)
# #### The unzipped files are in colab disk and is assessible from the title of the zip file. In this case the file name is 'data-2019'

# %%
# !unzip -q "/content/drive/My Drive/Colab Notebooks/VehicleDetection/_data.zip"
# !unzip "/content/drive/My Drive/Colab Notebooks/VehicleDetection/annot_folder.zip" -d "/content/drive/My Drive/Colab Notebooks/VehicleDetection/data4YOLO"
# !unzip "/content/drive/My Drive/Colab Notebooks/VehicleDetection/image_folder.zip" -d "/content/drive/My Drive/Colab Notebooks/VehicleDetection/data4YOLO"

# %% [markdown]
# ## CD into Base Path

# %%
# %cd /content/drive/My Drive/Colab Notebooks/VehicleDetection/keras-yolo3-master
# Out:
# /content/drive/My Drive/Colab Notebooks/VehicleDetection/keras-yolo3-master

# %% [markdown]
# # Step 1: Upload the configuration file (OPTIONAL)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a06e7407-e9dd-400f-90c6-a7bebc2939b9" name="files[]" multiple disabled />
#      <output id="result-a06e7407-e9dd-400f-90c6-a7bebc2939b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gmail_shorterlabels_4.h5 to gmail_shorterlabels_4.h5

# %% [markdown]
# # Step 2: Generate anchors for your dataset
# ********** Import thing about this step **************
# The .json file ran with gen_anchors contains anchors values (9?). You need to
# change these values with what has been generated with the output of this step for better bounding boxes.
#
# ALSO
# The .json file is EVERYTHING to run train the yolo model.
# important attributes to change include:
# - anchors (produced by this cell)
# - labels (what labels seen from the (VOC) which are .xml files
# - saved_weight name: The weights to read and save
# **** If the weights are not present (.h5) then will use backend.h5

# %%
# !python gen_anchors.py -c 'yolo_ROB535.json'

# %% [markdown]
# # Step 3: Start the training process

# %%
# !python train.py -c 'yolo_ROB535.json'
# Out:
# Using TensorFlow backend.
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'1': 2964, '2': 1073, '3': 148, '0': 73}
#
# Given labels: 	['0', '1', '2', '3']
#
# Training on: 	['0', '1', '2', '3']
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# # Step 4: Perform detection using trained weights on image, set of images, video, or webcam

# %%
# !python predict.py -c yolo_ROB535.json.json' -i '../data4YOLO/image_folder/00028_image.jpg'

# %% [markdown]
# # Step 5: See the Output which has been placed in folder output

# %%
import cv2
from google.colab.patches import cv2_imshow   
image = cv2.imread('output/00028_image.jpg')
cv2_imshow(image)
